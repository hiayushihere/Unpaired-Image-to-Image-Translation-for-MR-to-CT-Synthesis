# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ct-to-mri-cgan/Dataset/sources.txt
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1860.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1979.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri99.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri478.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1608.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1379.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2058.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1589.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri678.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2440.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri959.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri750.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1628.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2288.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri699.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2019.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri328.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri280.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1498.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri969.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri310.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1660.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri799.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1270.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2148.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1980.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1939.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri388.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri780.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1758.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1019.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1759.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri200.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri320.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2038.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1540.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri538.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2469.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1410.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1269.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2358.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1930.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1129.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1968.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1249.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1579.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2240.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1339.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2229.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1738.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri69.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1938.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2428.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1128.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1208.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1888.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1458.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri250.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1110.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1448.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1418.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2108.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1519.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1028.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1430.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri809.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri609.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1900.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1889.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri78.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri698.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1450.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1809.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1118.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri639.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1239.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1868.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1020.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2239.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1440.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri100.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1718.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri778.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri500.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1780.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1348.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri20.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1200.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1568.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri770.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri10.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri479.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri409.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri38.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1539.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1570.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri729.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1789.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1268.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri218.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1869.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri418.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1279.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri258.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2429.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri810.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri499.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2450.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1479.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri68.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri168.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1700.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1219.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2320.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri139.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2259.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2029.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2398.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2078.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1548.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri110.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1459.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri458.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2300.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri648.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri189.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1740.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1168.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri468.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1770.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri119.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri618.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri848.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2269.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri879.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2060.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri70.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri378.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1898.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1739.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1699.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri968.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri568.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1010.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri98.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1508.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1310.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1668.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri868.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri349.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1238.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri908.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1828.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1230.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1039.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1069.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri739.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri779.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1029.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1690.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri369.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri679.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri720.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1419.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri590.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2138.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1468.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1390.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri488.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri329.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri728.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri239.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1030.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri39.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri448.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri190.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri19.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1800.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri740.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2169.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri160.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri600.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri900.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri650.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2449.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri730.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri80.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri529.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri59.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1008.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1549.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1858.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1879.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri948.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri269.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2368.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1318.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1840.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2150.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1070.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2380.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri719.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri450.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri928.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1090.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri580.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2248.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri638.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1278.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2018.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1698.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri530.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri599.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1180.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri899.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1669.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri800.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri438.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri330.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2250.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri999.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1250.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri970.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1530.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1350.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri158.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1328.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri828.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1688.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2238.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri88.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1480.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri869.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri889.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri619.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri40.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1189.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2249.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1960.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1599.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2360.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1108.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri979.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2438.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri859.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri268.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2089.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2379.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri569.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1678.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1060.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2459.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri819.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2158.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri640.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2359.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2040.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri818.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2370.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2389.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2130.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1550.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri560.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri539.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1289.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1590.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri359.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2059.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1989.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2099.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri108.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2339.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1478.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1650.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2048.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri589.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1990.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2080.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri680.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2219.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri60.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri909.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1909.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2299.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2199.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1948.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri299.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2338.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri248.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1908.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1609.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1048.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1130.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1818.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1598.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1080.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1949.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1170.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1068.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri379.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1528.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri629.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri149.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2189.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri668.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri368.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1999.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2348.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2458.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri380.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri298.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri159.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2318.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1149.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1829.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri459.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1240.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1000.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1918.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2480.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1779.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri338.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri178.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri919.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2409.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1689.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1940.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2448.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri289.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri18.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1049.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2410.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1380.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri839.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri410.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri140.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2418.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1460.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri199.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1648.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1439.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2049.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1510.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri578.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri790.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1018.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri79.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2280.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri829.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1119.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1499.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri389.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri180.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri748.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1848.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2258.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1790.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1899.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1369.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2090.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1929.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri48.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1158.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri550.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1640.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1140.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri179.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri138.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1349.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri270.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri49.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri260.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2030.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1629.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri860.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2308.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri339.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1658.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1878.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri279.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1649.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri319.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri229.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1560.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2470.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1950.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1610.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri998.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri128.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2260.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri238.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1958.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1428.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2478.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1358.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri930.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1509.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2200.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1058.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2159.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2168.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri489.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri230.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1808.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri710.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri520.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri718.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri148.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1569.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri548.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1408.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1489.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri709.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri688.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri309.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2039.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2160.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri220.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri509.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1220.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1799.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri950.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri738.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri90.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri58.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri440.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri670.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2319.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri480.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2268.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri958.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri399.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri769.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2400.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2350.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2309.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri929.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2479.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri528.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2008.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1830.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2419.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri130.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1538.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1120.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1719.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri219.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1839.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1050.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri340.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2050.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1038.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1338.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri890.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2388.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1079.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri598.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1138.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1199.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1838.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1729.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1558.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri228.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2028.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2129.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1259.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1040.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1280.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri570.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1109.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1859.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri798.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri439.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2328.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1748.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri768.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2020.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri630.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1378.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri358.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1309.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1400.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2279.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1500.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1870.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2009.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri858.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1680.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri420.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1978.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri669.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1399.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2349.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri898.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1319.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2178.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2118.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri878.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri120.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri50.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1928.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri960.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri788.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri659.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1998.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri198.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2390.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1768.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2270.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri559.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1228.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri118.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1728.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1169.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri830.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri249.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1218.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2218.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1988.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri700.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri608.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri658.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri390.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri370.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri129.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1750.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1600.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri789.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1298.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri838.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2378.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1518.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2369.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2460.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1578.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1229.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1009.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2290.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2069.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1710.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1880.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri849.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri518.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri870.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1100.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri9.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1300.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2170.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri938.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri419.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri470.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1659.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1619.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1190.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1559.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1148.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri820.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri910.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2208.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2140.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1810.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri880.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1429.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1798.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1260.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2188.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1320.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1370.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri689.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri508.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1620.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2110.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2430.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri988.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1359.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1179.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1099.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1850.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1389.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2068.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri490.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1469.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri28.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1059.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1299.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2220.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri760.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri400.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2179.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1288.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri170.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1849.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1398.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1449.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2139.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2010.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2420.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri89.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2149.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri428.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2310.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri510.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1749.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri30.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri558.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1820.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1088.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2109.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri8.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1638.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2128.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2230.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1248.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1529.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1618.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2468.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2408.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1209.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1078.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri918.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri300.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri318.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri188.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri169.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1340.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1969.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2079.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri29.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1769.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri940.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2070.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2228.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri109.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri808.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2210.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri588.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1490.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1670.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1788.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri549.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1470.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2120.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1388.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1258.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1150.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1159.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1890.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1098.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri579.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2439.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri649.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2000.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1778.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1139.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1089.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2399.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri628.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri408.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2278.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri150.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1360.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1368.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1198.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri888.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri360.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1959.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri449.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2329.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri620.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri460.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1819.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri690.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri398.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri348.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1910.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1520.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1488.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2100.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2180.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1760.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri840.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1920.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1708.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1210.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2209.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1970.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri430.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1630.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri920.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1188.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri660.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri759.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri540.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri290.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri980.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri278.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2098.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri429.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri519.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1160.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1709.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1178.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri350.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1409.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri610.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri758.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri308.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2298.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri989.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1730.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1308.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2289.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1919.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1679.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2190.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2198.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri208.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2340.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri749.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri978.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri469.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2088.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri210.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri240.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri209.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri850.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1420.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri939.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri708.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2119.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1329.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1330.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1438.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri498.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1580.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri990.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1588.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri2330.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1639.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri949.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri259.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1720.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri1290.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testB/mri288.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1870.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct628.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1929.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1550.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct498.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1620.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1238.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct950.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct569.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1020.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1199.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct829.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1470.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct648.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct2209.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct760.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1359.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct2048.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct848.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct68.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct2380.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct48.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1489.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct2390.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct288.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1060.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct2298.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1790.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1820.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1768.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct258.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct2169.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct649.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct1048.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/testA/ct2358.png
# ...
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct993.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1136.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1015.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct694.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct26.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1042.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct247.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2402.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1556.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1785.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct424.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1965.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1207.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1097.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct713.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1782.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct937.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2362.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1256.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1627.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct963.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct342.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct365.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1226.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct907.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1361.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2454.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2276.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2346.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct192.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1993.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct21.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1935.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1897.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct682.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2236.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct416.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1205.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2417.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1177.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct457.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1555.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct146.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct472.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1354.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct701.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct983.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2313.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2161.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct446.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct602.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1597.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct586.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct883.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct392.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1571.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct125.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1146.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2493.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct835.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct705.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct941.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct807.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct655.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2472.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1431.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2065.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct361.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1546.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1231.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct461.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1267.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1297.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2487.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1564.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct746.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1771.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct531.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct87.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2323.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct997.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1371.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct57.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1415.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2442.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2073.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2102.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct967.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1154.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct725.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct286.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1961.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1061.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2117.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2215.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1313.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2061.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2365.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct405.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1303.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2474.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct314.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct784.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1623.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1302.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2343.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct47.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2144.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct953.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct153.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1582.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1017.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1265.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct303.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct795.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2024.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct372.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2425.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct113.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct986.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1757.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct757.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1044.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1083.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct222.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct805.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1105.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct441.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1603.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct352.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2147.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1434.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1372.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1101.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct662.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1306.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct32.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1767.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct323.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct903.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct514.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct781.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct526.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1715.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct671.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct65.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1475.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2316.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2224.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2492.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct905.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1746.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1846.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1604.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct436.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1074.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1681.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2371.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1683.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1835.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct224.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1742.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1663.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct362.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1774.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1147.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1575.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1962.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct811.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2214.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1843.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1141.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct364.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1824.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1611.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct356.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct164.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1206.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct576.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct377.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct366.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1684.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2366.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2025.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2247.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct613.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct44.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct174.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2444.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1135.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1413.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct35.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct367.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2051.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct803.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2034.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1102.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1963.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct374.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1032.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1093.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1971.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2443.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1183.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1167.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct675.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2122.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct596.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct14.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2297.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct717.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1753.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2217.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2241.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct2232.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1242.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1665.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct447.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct846.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct353.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct1613.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct641.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct555.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct985.png
# /kaggle/input/ct-to-mri-cgan/Dataset/images/trainA/ct355.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct1367.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct1925.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct1823.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct1191.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct78.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct73.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct710.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct76.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct77.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct74.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct1350.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct1008.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct909.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct58.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/ct/ct75.png
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri675.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri606.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri371.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri605.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri523.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri387.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri521.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri313.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri334.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri607.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri611.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri612.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri522.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri531.jpg
# /kaggle/input/ct-to-mri-cgan/Dataset/unseen_demo_images/mri/mri532.jpg

# %%
# ===============================================================
# Install dependencies 
# ===============================================================
try:
    import lpips, pytorch_fid
except Exception:
    # !pip install --quiet lpips pytorch-fid
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.5 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.9 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 50.0 MB/s eta 0:00:0000:0100:01m
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.

# %%
# 1) Imports & Config
# -------------------------
import os, glob, csv, time, itertools, math
from datetime import timedelta
from PIL import Image
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms as T
from torchvision.utils import save_image

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

from pytorch_fid import fid_score
from lpips import LPIPS
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim


torch.backends.cudnn.benchmark = True

# %%
# -------------------------
# 2) Paths
# -------------------------
DATA_ROOT = "/kaggle/input/ct-to-mri-cgan/Dataset/images"
CT_TRAIN = os.path.join(DATA_ROOT, "trainA")   # CT images
MRI_TRAIN = os.path.join(DATA_ROOT, "trainB")  # MRI images
CT_TEST  = os.path.join(DATA_ROOT, "testA")
MRI_TEST = os.path.join(DATA_ROOT, "testB")

OUT_DIR = "outputs_ct2mri"
CKPT_DIR = os.path.join(OUT_DIR, "checkpoints")
PLOTS_DIR = os.path.join(OUT_DIR, "plots")
XAI_DIR = os.path.join(OUT_DIR, "xai")
GEN_DIR = os.path.join(OUT_DIR, "generated_ct2mri")
REAL_FOR_FID = os.path.join(OUT_DIR, "real_mri_for_fid")

for d in [OUT_DIR, CKPT_DIR, PLOTS_DIR, XAI_DIR, GEN_DIR, REAL_FOR_FID]:
    os.makedirs(d, exist_ok=True)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f" Using device: {DEVICE}")
# Out:
#  Using device: cuda

# %%
# -------------------------
# 3) Hyperparams
# -------------------------
IMAGE_SIZE = 256
BATCH_SIZE = 2
EPOCHS = 100
LR = 1e-4
# RMSprop specific: alpha is the smoothing constant (default is 0.99)
ALPHA = 0.99 
SAVE_EVERY = 10

lambda_cyc = 10.0
lambda_id  = 5.0
lambda_cut = 1.0

# %%
# -------------------------
# 4) Dataset & Transforms
# -------------------------
transform = T.Compose([
    T.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    T.Grayscale(),                 # force grayscale
    T.ToTensor(),
    T.Normalize([0.5], [0.5])      # [-1, 1]
])

class CTMRIDataset(Dataset):
    def __init__(self, ct_dir, mri_dir):
        exts = ("*.png","*.jpg","*.jpeg","*.bmp","*.tif","*.tiff")
        self.ct_paths = []
        self.mri_paths = []
        for e in exts:
            self.ct_paths += glob.glob(os.path.join(ct_dir, e))
            self.mri_paths += glob.glob(os.path.join(mri_dir, e))
        self.ct_paths = sorted(self.ct_paths)
        self.mri_paths = sorted(self.mri_paths)
        self.length = min(len(self.ct_paths), len(self.mri_paths))

    def __len__(self): return self.length

    def __getitem__(self, idx):
        ct_img  = Image.open(self.ct_paths[idx]).convert('L')
        mri_img = Image.open(self.mri_paths[idx]).convert('L')
        return transform(ct_img), transform(mri_img)

train_ds = CTMRIDataset(CT_TRAIN, MRI_TRAIN)
dataloader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True, drop_last=True)
print(f" Train pairs: {len(train_ds)}")
# Out:
#  Train pairs: 1742

# %%
# -------------------------
# 5) Model (HybridCycleCUT)
# -------------------------
class ResBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.block = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(dim, dim, 3),
            nn.InstanceNorm2d(dim),
            nn.ReLU(True),
            nn.ReflectionPad2d(1),
            nn.Conv2d(dim, dim, 3),
            nn.InstanceNorm2d(dim)
        )
    def forward(self, x): return x + self.block(x)

class Generator(nn.Module):
    def __init__(self, in_ch=1, out_ch=1, n_res=9, base=32):
        super().__init__()
        model = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(in_ch, base, 7),
            nn.InstanceNorm2d(base), nn.ReLU(True),
            nn.Conv2d(base, base*2, 3, 2, 1),
            nn.InstanceNorm2d(base*2), nn.ReLU(True),
            nn.Conv2d(base*2, base*4, 3, 2, 1),
            nn.InstanceNorm2d(base*4), nn.ReLU(True),
        ]
        for _ in range(n_res):
            model += [ResBlock(base*4)]
        model += [
            nn.ConvTranspose2d(base*4, base*2, 3, 2, 1, 1),
            nn.InstanceNorm2d(base*2), nn.ReLU(True),
            nn.ConvTranspose2d(base*2, base, 3, 2, 1, 1),
            nn.InstanceNorm2d(base), nn.ReLU(True),
            nn.ReflectionPad2d(3),
            nn.Conv2d(base, out_ch, 7),
            nn.Tanh()
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x): return self.model(x)

class Discriminator(nn.Module):
    def __init__(self, in_ch=1, base=64):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(in_ch, base, 4, 2, 1),
            nn.LeakyReLU(0.2, inplace=False), 
            nn.Conv2d(base, base*2, 4, 2, 1),
            nn.InstanceNorm2d(base*2),
            nn.LeakyReLU(0.2, inplace=False), 
            nn.Conv2d(base*2, base*4, 4, 2, 1),
            nn.InstanceNorm2d(base*4),
            nn.LeakyReLU(0.2, inplace=False),  
            nn.Conv2d(base*4, 1, 4, 1, 1)
        )
    def forward(self, x): return self.model(x)

class MLP(nn.Module):
    def __init__(self, dim=128):
        super().__init__()
        self.layer = nn.Sequential(
            nn.Linear(dim, dim), nn.ReLU(True),
            nn.Linear(dim, dim)
        )
    def forward(self, x): return self.layer(x)

class HybridCycleCUT(nn.Module):
    def __init__(self):
        super().__init__()
        self.G_A2B = Generator()  # CT → MRI
        self.G_B2A = Generator()  # MRI → CT
        self.D_A = Discriminator()
        self.D_B = Discriminator()
        self.mlp = MLP(dim=128)

    def _feat_early(self, x, gen):
        # take features right after the second downsample (C=128 at 1/4 res)
        feats = []
        for i, layer in enumerate(gen.model):
            x = layer(x)
            # After third element block: conv->inorm->relu (index up to ~8) we are at 1/4
            feats.append(x)
            # capture at index where channels==128
        # find earliest 128C map (heuristic)
        for f in feats:
            if f.dim()==4 and f.shape[1]==128:
                return f
        return feats[-1]

    def forward(self, real_A, real_B):
        fake_B = self.G_A2B(real_A)
        fake_A = self.G_B2A(real_B)
        rec_A  = self.G_B2A(fake_B)
        rec_B  = self.G_A2B(fake_A)

        # CUT features (project patches)
        feat_real_A = self._feat_early(real_A, self.G_B2A)  # use opposite net to compare
        feat_fake_B = self._feat_early(fake_B, self.G_B2A)
        feat_real_B = self._feat_early(real_B, self.G_A2B)
        feat_fake_A = self._feat_early(fake_A, self.G_A2B)

        def proj(f):  # (B,C,H,W)->(B,N,128)
            B,C,H,W = f.shape
            f = f.view(B, C, H*W).permute(0,2,1)  # (B,N,C)
            return self.mlp(f)
        return fake_B, fake_A, rec_A, rec_B, proj(feat_real_A), proj(feat_fake_B), proj(feat_real_B), proj(feat_fake_A)

model = HybridCycleCUT().to(DEVICE)

# %%
# -------------------------
# 6) Losses & Opts
# -------------------------
criterionGAN = nn.MSELoss()
criterionL1  = nn.L1Loss()

def gan_loss(pred, target=True):
    return criterionGAN(pred, torch.ones_like(pred) if target else torch.zeros_like(pred))

def patchnce_loss(f_s, f_t, tau=0.07):
    # f_s,f_t: (B,N,D)
    f_s = F.normalize(f_s, dim=-1)
    f_t = F.normalize(f_t, dim=-1)
    sim = torch.bmm(f_s, f_t.transpose(1,2)) / tau  # (B,N,N)
    labels = torch.arange(f_s.size(1), device=f_s.device).expand(f_s.size(0), -1)
    return F.cross_entropy(sim, labels)

# Switched Adam to RMSprop
opt_G = optim.RMSprop(
    itertools.chain(model.G_A2B.parameters(), model.G_B2A.parameters(), model.mlp.parameters()), 
    lr=LR, 
    alpha=ALPHA
)
opt_D = optim.RMSprop(
    itertools.chain(model.D_A.parameters(), model.D_B.parameters()), 
    lr=LR, 
    alpha=ALPHA
)

scaler = torch.cuda.amp.GradScaler()
# Out:
# /tmp/ipykernel_38/1625977077.py:30: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %%
# -------------------------
# 7) Logging CSV
# -------------------------
metrics_csv = os.path.join(OUT_DIR, "training_log.csv")
with open(metrics_csv, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['epoch','G_GAN','G_Cycle','G_Id','G_CUT','G_total','D_real','D_fake','D_total','lr','time_sec'])

# %%
# -------------------------
# 8) Training Loop (100 epochs) with ETA
# -------------------------
print(" Starting training...")

start_time_all = time.time()
epoch_times = []

for epoch in range(1, EPOCHS+1):
    t0 = time.time()
    meter_G_GAN = meter_G_Cycle = meter_G_Id = meter_G_CUT = meter_G = 0.0
    meter_D_real = meter_D_fake = meter_D = 0.0
    n_samples = 0

    model.train()
    for real_A, real_B in dataloader:
        real_A, real_B = real_A.to(DEVICE), real_B.to(DEVICE)
        bs = real_A.size(0)

        with torch.cuda.amp.autocast():
            (fake_B, fake_A, rec_A, rec_B,
             proj_real_A, proj_fake_B, proj_real_B, proj_fake_A) = model(real_A, real_B)

            # Discriminator
            D_A_real = gan_loss(model.D_A(real_A), True)
            D_A_fake = gan_loss(model.D_A(fake_A.detach()), False)
            D_B_real = gan_loss(model.D_B(real_B), True)
            D_B_fake = gan_loss(model.D_B(fake_B.detach()), False)
            loss_D = 0.5*(D_A_real + D_A_fake) + 0.5*(D_B_real + D_B_fake)

        opt_D.zero_grad()
        scaler.scale(loss_D).backward()
        scaler.step(opt_D)

        with torch.cuda.amp.autocast():
            # Generator
            G_A = gan_loss(model.D_A(fake_A), True)
            G_B = gan_loss(model.D_B(fake_B), True)
            loss_G_GAN = 0.5*(G_A + G_B)

            loss_cycle = criterionL1(rec_A, real_A) + criterionL1(rec_B, real_B)
            loss_id    = criterionL1(model.G_B2A(real_A), real_A) + criterionL1(model.G_A2B(real_B), real_B)

            loss_cut = patchnce_loss(proj_real_A, proj_fake_B) + patchnce_loss(proj_real_B, proj_fake_A)

            loss_G = loss_G_GAN + lambda_cyc*loss_cycle + lambda_id*loss_id + lambda_cut*loss_cut

        opt_G.zero_grad()
        scaler.scale(loss_G).backward()
        scaler.step(opt_G)
        scaler.update()

        # meters
        meter_G_GAN   += loss_G_GAN.item()*bs
        meter_G_Cycle += loss_cycle.item()*bs
        meter_G_Id    += loss_id.item()*bs
        meter_G_CUT   += loss_cut.item()*bs
        meter_G       += loss_G.item()*bs
        meter_D_real  += (D_A_real + D_B_real).item()*bs
        meter_D_fake  += (D_A_fake + D_B_fake).item()*bs
        meter_D       += loss_D.item()*bs
        n_samples     += bs

    # averages
    meter_G_GAN   /= n_samples
    meter_G_Cycle /= n_samples
    meter_G_Id    /= n_samples
    meter_G_CUT   /= n_samples
    meter_G       /= n_samples
    meter_D_real  /= n_samples
    meter_D_fake  /= n_samples
    meter_D       /= n_samples

    t1 = time.time()
    epoch_time = t1 - t0
    epoch_times.append(epoch_time)
    avg_epoch = np.mean(epoch_times)
    remaining = (EPOCHS - epoch) * avg_epoch
    # Pretty formats
    def fmt_secs(s): 
        return f"{int(s//3600)}h{int((s%3600)//60)}m" if s>=3600 else (f"{int(s//60)}m{int(s%60)}s" if s>=60 else f"{s:.1f}s")

    log_line = (f"Epoch {epoch:3d} | G:{meter_G:.4f} | D:{meter_D:.4f} | "
                f"GAN:{meter_G_GAN:.4f} | Cyc:{meter_G_Cycle:.4f} | Id:{meter_G_Id:.4f} | CUT:{meter_G_CUT:.4f} | "
                f"Time:{fmt_secs(epoch_time)} | ETA:{fmt_secs(remaining)}")
    print(log_line)

    # CSV
    with open(metrics_csv, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([
            epoch, f"{meter_G_GAN:.6f}", f"{meter_G_Cycle:.6f}", f"{meter_G_Id:.6f}", f"{meter_G_CUT:.6f}",
            f"{meter_G:.6f}", f"{meter_D_real:.6f}", f"{meter_D_fake:.6f}", f"{meter_D:.6f}",
            f"{opt_G.param_groups[0]['lr']:.6f}", f"{epoch_time:.3f}"
        ])

    # checkpoints
    if epoch % SAVE_EVERY == 0 or epoch == EPOCHS:
        torch.save({
            'epoch': epoch,
            'model': model.state_dict(),
            'opt_G': opt_G.state_dict(),
            'opt_D': opt_D.state_dict(),
        }, os.path.join(CKPT_DIR, f'ct2mri_hybrid_epoch_{epoch}.pth'))

total_time = time.time() - start_time_all
print(f" Training complete in {int(total_time//60)}m {int(total_time%60)}s.")
# Out:
#  Starting training...
# /tmp/ipykernel_38/571432996.py:20: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /tmp/ipykernel_38/571432996.py:35: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch   1 | G:10.5360 | D:0.3625 | GAN:0.5483 | Cyc:0.2062 | Id:0.1883 | CUT:6.9843 | Time:4m30s | ETA:7h26m
# Epoch   2 | G:8.4028 | D:0.2526 | GAN:0.6732 | Cyc:0.1617 | Id:0.1479 | CUT:5.3727 | Time:4m27s | ETA:7h19m
# Epoch   3 | G:7.9625 | D:0.2343 | GAN:0.6992 | Cyc:0.1489 | Id:0.1344 | CUT:5.1020 | Time:4m27s | ETA:7h14m
# Epoch   4 | G:7.6951 | D:0.2229 | GAN:0.7139 | Cyc:0.1388 | Id:0.1230 | CUT:4.9777 | Time:4m27s | ETA:7h9m
# Epoch   5 | G:7.5590 | D:0.2195 | GAN:0.7150 | Cyc:0.1325 | Id:0.1170 | CUT:4.9342 | Time:4m27s | ETA:7h4m
# Epoch   6 | G:7.4228 | D:0.2174 | GAN:0.7189 | Cyc:0.1266 | Id:0.1107 | CUT:4.8847 | Time:4m27s | ETA:6h59m
# Epoch   7 | G:7.2997 | D:0.2151 | GAN:0.7204 | Cyc:0.1208 | Id:0.1051 | CUT:4.8456 | Time:4m27s | ETA:6h55m
# Epoch   8 | G:7.2130 | D:0.2144 | GAN:0.7236 | Cyc:0.1157 | Id:0.1011 | CUT:4.8269 | Time:4m27s | ETA:6h50m
# Epoch   9 | G:7.1582 | D:0.2103 | GAN:0.7307 | Cyc:0.1128 | Id:0.0979 | CUT:4.8104 | Time:4m27s | ETA:6h46m
# Epoch  10 | G:7.1352 | D:0.2052 | GAN:0.7370 | Cyc:0.1110 | Id:0.0960 | CUT:4.8083 | Time:4m27s | ETA:6h41m
# Epoch  11 | G:7.0449 | D:0.2034 | GAN:0.7405 | Cyc:0.1067 | Id:0.0921 | CUT:4.7772 | Time:4m27s | ETA:6h37m
# Epoch  12 | G:7.0141 | D:0.1989 | GAN:0.7492 | Cyc:0.1044 | Id:0.0899 | CUT:4.7712 | Time:4m27s | ETA:6h32m
# Epoch  13 | G:6.9684 | D:0.1971 | GAN:0.7499 | Cyc:0.1023 | Id:0.0876 | CUT:4.7575 | Time:4m27s | ETA:6h28m
# Epoch  14 | G:6.9263 | D:0.1963 | GAN:0.7543 | Cyc:0.0999 | Id:0.0852 | CUT:4.7466 | Time:4m27s | ETA:6h23m
# Epoch  15 | G:6.9006 | D:0.1950 | GAN:0.7534 | Cyc:0.0989 | Id:0.0835 | CUT:4.7404 | Time:4m27s | ETA:6h19m
# Epoch  16 | G:6.8693 | D:0.1914 | GAN:0.7646 | Cyc:0.0962 | Id:0.0809 | CUT:4.7387 | Time:4m27s | ETA:6h14m
# Epoch  17 | G:6.8474 | D:0.1901 | GAN:0.7618 | Cyc:0.0955 | Id:0.0796 | CUT:4.7324 | Time:4m27s | ETA:6h10m
# Epoch  18 | G:6.8211 | D:0.1882 | GAN:0.7680 | Cyc:0.0936 | Id:0.0784 | CUT:4.7251 | Time:4m27s | ETA:6h5m
# Epoch  19 | G:6.7975 | D:0.1874 | GAN:0.7712 | Cyc:0.0916 | Id:0.0762 | CUT:4.7291 | Time:4m27s | ETA:6h1m
# Epoch  20 | G:6.7739 | D:0.1902 | GAN:0.7632 | Cyc:0.0907 | Id:0.0757 | CUT:4.7256 | Time:4m27s | ETA:5h56m
# Epoch  21 | G:6.7581 | D:0.1886 | GAN:0.7668 | Cyc:0.0898 | Id:0.0739 | CUT:4.7232 | Time:4m27s | ETA:5h52m
# Epoch  22 | G:6.7409 | D:0.1967 | GAN:0.7579 | Cyc:0.0890 | Id:0.0731 | CUT:4.7277 | Time:4m27s | ETA:5h47m
# Epoch  23 | G:6.7176 | D:0.1938 | GAN:0.7627 | Cyc:0.0877 | Id:0.0715 | CUT:4.7207 | Time:4m27s | ETA:5h43m
# Epoch  24 | G:6.6910 | D:0.1943 | GAN:0.7614 | Cyc:0.0866 | Id:0.0705 | CUT:4.7111 | Time:4m27s | ETA:5h38m
# Epoch  25 | G:6.6610 | D:0.1976 | GAN:0.7570 | Cyc:0.0851 | Id:0.0694 | CUT:4.7058 | Time:4m27s | ETA:5h34m
# Epoch  26 | G:6.6756 | D:0.1906 | GAN:0.7696 | Cyc:0.0854 | Id:0.0684 | CUT:4.7098 | Time:4m27s | ETA:5h29m
# Epoch  27 | G:6.6352 | D:0.1920 | GAN:0.7673 | Cyc:0.0829 | Id:0.0677 | CUT:4.7004 | Time:4m27s | ETA:5h25m
# Epoch  28 | G:6.6238 | D:0.1894 | GAN:0.7753 | Cyc:0.0819 | Id:0.0663 | CUT:4.6982 | Time:4m27s | ETA:5h21m
# Epoch  29 | G:6.6080 | D:0.1834 | GAN:0.7803 | Cyc:0.0806 | Id:0.0654 | CUT:4.6945 | Time:4m27s | ETA:5h16m
# Epoch  30 | G:6.5908 | D:0.1877 | GAN:0.7773 | Cyc:0.0803 | Id:0.0649 | CUT:4.6854 | Time:4m27s | ETA:5h12m
# Epoch  31 | G:6.5974 | D:0.1840 | GAN:0.7779 | Cyc:0.0803 | Id:0.0644 | CUT:4.6946 | Time:4m27s | ETA:5h7m
# Epoch  32 | G:6.5502 | D:0.1840 | GAN:0.7834 | Cyc:0.0774 | Id:0.0625 | CUT:4.6801 | Time:4m27s | ETA:5h3m
# Epoch  33 | G:6.5503 | D:0.1850 | GAN:0.7827 | Cyc:0.0780 | Id:0.0619 | CUT:4.6780 | Time:4m27s | ETA:4h58m
# Epoch  34 | G:6.5627 | D:0.1812 | GAN:0.7869 | Cyc:0.0791 | Id:0.0625 | CUT:4.6722 | Time:4m27s | ETA:4h54m
# Epoch  35 | G:6.5150 | D:0.1802 | GAN:0.7905 | Cyc:0.0759 | Id:0.0607 | CUT:4.6614 | Time:4m27s | ETA:4h49m
# Epoch  36 | G:6.5080 | D:0.1777 | GAN:0.7902 | Cyc:0.0753 | Id:0.0603 | CUT:4.6630 | Time:4m27s | ETA:4h45m
# Epoch  37 | G:6.5265 | D:0.1745 | GAN:0.8019 | Cyc:0.0755 | Id:0.0599 | CUT:4.6705 | Time:4m27s | ETA:4h40m
# Epoch  38 | G:6.4906 | D:0.1712 | GAN:0.7992 | Cyc:0.0734 | Id:0.0591 | CUT:4.6613 | Time:4m27s | ETA:4h36m
# Epoch  39 | G:6.4919 | D:0.1784 | GAN:0.7905 | Cyc:0.0745 | Id:0.0592 | CUT:4.6606 | Time:4m27s | ETA:4h31m
# Epoch  40 | G:6.4711 | D:0.1767 | GAN:0.7938 | Cyc:0.0730 | Id:0.0582 | CUT:4.6557 | Time:4m27s | ETA:4h27m
# Epoch  41 | G:6.4718 | D:0.1717 | GAN:0.8028 | Cyc:0.0733 | Id:0.0579 | CUT:4.6463 | Time:4m27s | ETA:4h23m
# Epoch  42 | G:6.4687 | D:0.1734 | GAN:0.7983 | Cyc:0.0730 | Id:0.0575 | CUT:4.6522 | Time:4m27s | ETA:4h18m
# Epoch  43 | G:6.4599 | D:0.1727 | GAN:0.8007 | Cyc:0.0725 | Id:0.0574 | CUT:4.6472 | Time:4m27s | ETA:4h14m
# Epoch  44 | G:6.4517 | D:0.1709 | GAN:0.8062 | Cyc:0.0718 | Id:0.0572 | CUT:4.6415 | Time:4m27s | ETA:4h9m
# Epoch  45 | G:6.4241 | D:0.1676 | GAN:0.8072 | Cyc:0.0699 | Id:0.0559 | CUT:4.6384 | Time:4m27s | ETA:4h5m
# Epoch  46 | G:6.4204 | D:0.1702 | GAN:0.8055 | Cyc:0.0702 | Id:0.0555 | CUT:4.6358 | Time:4m27s | ETA:4h0m
# Epoch  47 | G:6.4257 | D:0.1621 | GAN:0.8157 | Cyc:0.0698 | Id:0.0552 | CUT:4.6357 | Time:4m27s | ETA:3h56m
# Epoch  48 | G:6.4253 | D:0.1707 | GAN:0.8033 | Cyc:0.0705 | Id:0.0556 | CUT:4.6392 | Time:4m27s | ETA:3h51m
# Epoch  49 | G:6.3859 | D:0.1645 | GAN:0.8130 | Cyc:0.0672 | Id:0.0538 | CUT:4.6325 | Time:4m27s | ETA:3h47m
# Epoch  50 | G:6.3911 | D:0.1660 | GAN:0.8111 | Cyc:0.0681 | Id:0.0541 | CUT:4.6280 | Time:4m27s | ETA:3h42m
# Epoch  51 | G:6.3810 | D:0.1699 | GAN:0.8022 | Cyc:0.0678 | Id:0.0533 | CUT:4.6340 | Time:4m27s | ETA:3h38m
# Epoch  52 | G:6.3895 | D:0.1653 | GAN:0.8139 | Cyc:0.0682 | Id:0.0534 | CUT:4.6264 | Time:4m27s | ETA:3h34m
# Epoch  53 | G:6.3634 | D:0.1682 | GAN:0.8078 | Cyc:0.0667 | Id:0.0522 | CUT:4.6275 | Time:4m27s | ETA:3h29m
# Epoch  54 | G:6.3701 | D:0.1687 | GAN:0.8066 | Cyc:0.0674 | Id:0.0525 | CUT:4.6271 | Time:4m27s | ETA:3h25m
# Epoch  55 | G:6.3760 | D:0.1689 | GAN:0.8052 | Cyc:0.0674 | Id:0.0525 | CUT:4.6338 | Time:4m27s | ETA:3h20m
# Epoch  56 | G:6.3588 | D:0.1652 | GAN:0.8179 | Cyc:0.0660 | Id:0.0514 | CUT:4.6238 | Time:4m27s | ETA:3h16m
# Epoch  57 | G:6.3487 | D:0.1682 | GAN:0.8068 | Cyc:0.0661 | Id:0.0516 | CUT:4.6224 | Time:4m27s | ETA:3h11m
# Epoch  58 | G:6.3502 | D:0.1652 | GAN:0.8145 | Cyc:0.0656 | Id:0.0513 | CUT:4.6233 | Time:4m27s | ETA:3h7m
# Epoch  59 | G:6.3211 | D:0.1685 | GAN:0.8060 | Cyc:0.0641 | Id:0.0504 | CUT:4.6222 | Time:4m27s | ETA:3h2m
# Epoch  60 | G:6.3340 | D:0.1654 | GAN:0.8132 | Cyc:0.0649 | Id:0.0502 | CUT:4.6203 | Time:4m27s | ETA:2h58m
# Epoch  61 | G:6.3330 | D:0.1673 | GAN:0.8114 | Cyc:0.0651 | Id:0.0507 | CUT:4.6176 | Time:4m26s | ETA:2h53m
# Epoch  62 | G:6.3181 | D:0.1649 | GAN:0.8126 | Cyc:0.0636 | Id:0.0496 | CUT:4.6212 | Time:4m26s | ETA:2h49m
# Epoch  63 | G:6.3296 | D:0.1626 | GAN:0.8166 | Cyc:0.0641 | Id:0.0496 | CUT:4.6236 | Time:4m26s | ETA:2h44m
# Epoch  64 | G:6.3050 | D:0.1608 | GAN:0.8205 | Cyc:0.0631 | Id:0.0489 | CUT:4.6090 | Time:4m26s | ETA:2h40m
# Epoch  65 | G:6.3131 | D:0.1662 | GAN:0.8113 | Cyc:0.0642 | Id:0.0497 | CUT:4.6116 | Time:4m27s | ETA:2h36m
# Epoch  66 | G:6.3012 | D:0.1599 | GAN:0.8196 | Cyc:0.0626 | Id:0.0487 | CUT:4.6122 | Time:4m27s | ETA:2h31m
# Epoch  67 | G:6.2983 | D:0.1593 | GAN:0.8223 | Cyc:0.0623 | Id:0.0485 | CUT:4.6111 | Time:4m27s | ETA:2h27m
# Epoch  68 | G:6.2920 | D:0.1557 | GAN:0.8268 | Cyc:0.0618 | Id:0.0483 | CUT:4.6057 | Time:4m26s | ETA:2h22m
# Epoch  69 | G:6.2760 | D:0.1587 | GAN:0.8219 | Cyc:0.0614 | Id:0.0485 | CUT:4.5972 | Time:4m27s | ETA:2h18m
# Epoch  70 | G:6.2898 | D:0.1578 | GAN:0.8232 | Cyc:0.0617 | Id:0.0480 | CUT:4.6098 | Time:4m27s | ETA:2h13m
# Epoch  71 | G:6.2707 | D:0.1587 | GAN:0.8231 | Cyc:0.0609 | Id:0.0479 | CUT:4.5990 | Time:4m27s | ETA:2h9m
# Epoch  72 | G:6.2649 | D:0.1584 | GAN:0.8217 | Cyc:0.0605 | Id:0.0471 | CUT:4.6031 | Time:4m26s | ETA:2h4m
# Epoch  73 | G:6.2615 | D:0.1599 | GAN:0.8195 | Cyc:0.0605 | Id:0.0469 | CUT:4.6020 | Time:4m27s | ETA:2h0m
# Epoch  74 | G:6.2609 | D:0.1587 | GAN:0.8248 | Cyc:0.0602 | Id:0.0472 | CUT:4.5983 | Time:4m27s | ETA:1h55m
# Epoch  75 | G:6.2511 | D:0.1611 | GAN:0.8148 | Cyc:0.0599 | Id:0.0467 | CUT:4.6036 | Time:4m27s | ETA:1h51m
# Epoch  76 | G:6.2737 | D:0.1582 | GAN:0.8250 | Cyc:0.0607 | Id:0.0469 | CUT:4.6070 | Time:4m27s | ETA:1h46m
# Epoch  77 | G:6.2424 | D:0.1625 | GAN:0.8172 | Cyc:0.0593 | Id:0.0460 | CUT:4.6020 | Time:4m27s | ETA:1h42m
# Epoch  78 | G:6.2525 | D:0.1533 | GAN:0.8326 | Cyc:0.0592 | Id:0.0461 | CUT:4.5976 | Time:4m27s | ETA:1h38m
# Epoch  79 | G:6.2344 | D:0.1520 | GAN:0.8315 | Cyc:0.0584 | Id:0.0454 | CUT:4.5921 | Time:4m27s | ETA:1h33m
# Epoch  80 | G:6.2354 | D:0.1598 | GAN:0.8217 | Cyc:0.0590 | Id:0.0453 | CUT:4.5976 | Time:4m27s | ETA:1h29m
# Epoch  81 | G:6.2329 | D:0.1556 | GAN:0.8277 | Cyc:0.0583 | Id:0.0450 | CUT:4.5971 | Time:4m27s | ETA:1h24m
# Epoch  82 | G:6.2159 | D:0.1595 | GAN:0.8191 | Cyc:0.0579 | Id:0.0448 | CUT:4.5942 | Time:4m27s | ETA:1h20m
# Epoch  83 | G:6.2247 | D:0.1579 | GAN:0.8247 | Cyc:0.0579 | Id:0.0448 | CUT:4.5975 | Time:4m27s | ETA:1h15m
# Epoch  84 | G:6.2055 | D:0.1611 | GAN:0.8179 | Cyc:0.0573 | Id:0.0443 | CUT:4.5934 | Time:4m27s | ETA:1h11m
# Epoch  85 | G:6.2267 | D:0.1564 | GAN:0.8275 | Cyc:0.0580 | Id:0.0445 | CUT:4.5968 | Time:4m26s | ETA:1h6m
# Epoch  86 | G:6.2279 | D:0.1561 | GAN:0.8285 | Cyc:0.0579 | Id:0.0447 | CUT:4.5974 | Time:4m27s | ETA:1h2m
# Epoch  87 | G:6.2077 | D:0.1573 | GAN:0.8271 | Cyc:0.0569 | Id:0.0436 | CUT:4.5935 | Time:4m27s | ETA:57m56s
# Epoch  88 | G:6.2173 | D:0.1578 | GAN:0.8242 | Cyc:0.0581 | Id:0.0440 | CUT:4.5923 | Time:4m27s | ETA:53m28s
# Epoch  89 | G:6.2164 | D:0.1520 | GAN:0.8314 | Cyc:0.0578 | Id:0.0445 | CUT:4.5840 | Time:4m27s | ETA:49m1s
# Epoch  90 | G:6.2272 | D:0.1553 | GAN:0.8270 | Cyc:0.0585 | Id:0.0440 | CUT:4.5953 | Time:4m26s | ETA:44m34s
# Epoch  91 | G:6.1984 | D:0.1552 | GAN:0.8278 | Cyc:0.0565 | Id:0.0430 | CUT:4.5901 | Time:4m27s | ETA:40m6s
# Epoch  92 | G:6.1860 | D:0.1541 | GAN:0.8299 | Cyc:0.0557 | Id:0.0429 | CUT:4.5848 | Time:4m27s | ETA:35m39s
# Epoch  93 | G:6.1975 | D:0.1508 | GAN:0.8335 | Cyc:0.0562 | Id:0.0432 | CUT:4.5862 | Time:4m27s | ETA:31m11s
# Epoch  94 | G:6.1794 | D:0.1554 | GAN:0.8262 | Cyc:0.0554 | Id:0.0426 | CUT:4.5864 | Time:4m27s | ETA:26m44s
# Epoch  95 | G:6.1881 | D:0.1560 | GAN:0.8265 | Cyc:0.0558 | Id:0.0426 | CUT:4.5904 | Time:4m27s | ETA:22m17s
# Epoch  96 | G:6.1897 | D:0.1535 | GAN:0.8323 | Cyc:0.0557 | Id:0.0427 | CUT:4.5863 | Time:4m27s | ETA:17m49s
# Epoch  97 | G:6.1791 | D:0.1548 | GAN:0.8268 | Cyc:0.0551 | Id:0.0424 | CUT:4.5896 | Time:4m27s | ETA:13m22s
# Epoch  98 | G:6.1803 | D:0.1551 | GAN:0.8282 | Cyc:0.0553 | Id:0.0422 | CUT:4.5880 | Time:4m27s | ETA:8m54s
# Epoch  99 | G:6.1793 | D:0.1586 | GAN:0.8231 | Cyc:0.0556 | Id:0.0420 | CUT:4.5904 | Time:4m27s | ETA:4m27s
# Epoch 100 | G:6.1892 | D:0.1536 | GAN:0.8344 | Cyc:0.0557 | Id:0.0423 | CUT:4.5860 | Time:4m27s | ETA:0.0s
#  Training complete in 445m 40s.

# %%
# -------------------------
# 9) Inference on testA (CT→MRI)
# -------------------------
model.eval()
test_paths = []
for e in ("*.png","*.jpg","*.jpeg","*.bmp","*.tif","*.tiff"):
    test_paths += glob.glob(os.path.join(CT_TEST, e))
test_paths = sorted(test_paths)

for p in tqdm(test_paths, desc="Generating MRI"):
    img = transform(Image.open(p).convert('L')).unsqueeze(0).to(DEVICE)
    with torch.no_grad(), torch.cuda.amp.autocast():
        fake = model.G_A2B(img)
    save_image((fake+1)/2, os.path.join(GEN_DIR, os.path.basename(p)))

print(" Generated images:", GEN_DIR)
# Out:
# Generating MRI:   0%|          | 0/744 [00:00<?, ?it/s]/tmp/ipykernel_38/1416006743.py:12: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():
# Generating MRI: 100%|██████████| 744/744 [00:25<00:00, 28.97it/s]
#  Generated images: outputs_ct2mri/generated_ct2mri

# %%
# -------------------------
# 10) Metrics (ALL test images)
# -------------------------
# Prepare real MRI folder for FID to ensure clean set
# (copy/resize testB images to REAL_FOR_FID to avoid surprises)
def copy_resized(src_dir, dst_dir):
    # clean dst
    for f in glob.glob(os.path.join(dst_dir, "*")):
        try: os.remove(f)
        except: pass
    paths = []
    for e in ("*.png","*.jpg","*.jpeg","*.bmp","*.tif","*.tiff"):
        paths += glob.glob(os.path.join(src_dir, e))
    paths = sorted(paths)
    for i, p in enumerate(paths):
        im = Image.open(p).convert('L').resize((IMAGE_SIZE, IMAGE_SIZE))
        im.save(os.path.join(dst_dir, f"real_{i:05d}.png"))

copy_resized(MRI_TEST, REAL_FOR_FID)

# FID
try:
    fid_val = fid_score.calculate_fid_given_paths([REAL_FOR_FID, GEN_DIR], batch_size=16, device=DEVICE, dims=2048)
    print(f"FID: {fid_val:.4f}")
except Exception as e:
    print("FID failed:", e)
    fid_val = "N/A"

# LPIPS / PSNR / SSIM / MSE / RMSE on index-aligned pairs (min length)
fake_paths = sorted(glob.glob(os.path.join(GEN_DIR, "*")))
real_paths = sorted(glob.glob(os.path.join(REAL_FOR_FID, "*")))
n_eval = min(len(fake_paths), len(real_paths))
print(f"Evaluating IQA on {n_eval} pairs ...")

lpips_model = LPIPS(net='vgg').to(DEVICE).eval()

s_lpips = s_psnr = s_ssim = s_mse = s_rmse = 0.0
for i in tqdm(range(n_eval), desc="IQA"):
    f_img = Image.open(fake_paths[i]).convert('L')
    r_img = Image.open(real_paths[i]).convert('L')

    # tensors in [-1,1] for LPIPS (to match earlier convention)
    f_t = T.ToTensor()(f_img).unsqueeze(0).to(DEVICE) * 2 - 1
    r_t = T.ToTensor()(r_img).unsqueeze(0).to(DEVICE) * 2 - 1

    with torch.no_grad():
        s_lpips += lpips_model(f_t, r_t).item()

    # for PSNR/SSIM use [0,1]
    f_np = (f_t.squeeze().detach().cpu().numpy()*0.5 + 0.5)
    r_np = (r_t.squeeze().detach().cpu().numpy()*0.5 + 0.5)

    s_psnr += psnr(r_np, f_np, data_range=1.0)
    s_ssim += ssim(r_np, f_np, data_range=1.0)
    mse_val = np.mean((f_np - r_np)**2)
    s_mse  += mse_val
    s_rmse += math.sqrt(mse_val)

metrics = {
    'fid': fid_val if isinstance(fid_val, float) else 'N/A',
    'lpips': s_lpips/n_eval if n_eval>0 else 'N/A',
    'psnr': s_psnr/n_eval if n_eval>0 else 'N/A',
    'ssim': s_ssim/n_eval if n_eval>0 else 'N/A',
    'rmse': s_rmse/n_eval if n_eval>0 else 'N/A',
    'mse' : s_mse/n_eval if n_eval>0 else 'N/A',
}
print("Final metrics:", metrics)

# Save metrics CSV and append to last row of training log
final_csv = os.path.join(OUT_DIR, "final_metrics.csv")
with open(final_csv, 'w', newline='') as f:
    writer = csv.writer(f); writer.writerow(metrics.keys()); writer.writerow(metrics.values())

# Update last row in training_log.csv
import pandas as pd
df = pd.read_csv(metrics_csv)
last_epoch = df['epoch'].iloc[-1]
for k in metrics.keys():
    if k not in df.columns:
        df[k] = ""
df.loc[df['epoch']==last_epoch, list(metrics.keys())] = list(metrics.values())
df.to_csv(metrics_csv, index=False)
# Out:
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:02<00:00, 43.5MB/s]
# 100%|██████████| 47/47 [00:04<00:00, 11.43it/s]
# 100%|██████████| 47/47 [00:02<00:00, 20.48it/s]
# FID: 101.7862
# Evaluating IQA on 744 pairs ...
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 219MB/s]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/vgg.pth
# IQA: 100%|██████████| 744/744 [00:15<00:00, 48.86it/s]
# Final metrics: {'fid': 101.78619203388212, 'lpips': 0.4903743561877999, 'psnr': 12.504180462689053, 'ssim': 0.26431016385659695, 'rmse': 0.2486594683338353, 'mse': 0.06781597447741816}

# %%
# -------------------------
# 11) Plots
# -------------------------
df = pd.read_csv(metrics_csv)
for col in ['G_total','D_total','G_GAN','G_Cycle','G_Id','G_CUT','D_real','D_fake','lr','time_sec']:
    if col not in df.columns:
        df[col] = 0.0

plt.figure(figsize=(10,5))
plt.plot(df['epoch'], df['G_total'], label='G_total', linewidth=2)
plt.plot(df['epoch'], df['D_total'], label='D_total', linewidth=2)
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('Generator vs Discriminator'); plt.legend(); plt.grid(True)
plt.tight_layout(); plt.savefig(os.path.join(PLOTS_DIR,'loss_G_vs_D.png'), dpi=200); plt.show()

plt.figure(figsize=(10,5))
plt.plot(df['epoch'], df['G_GAN'], label='G_GAN', linewidth=2)
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('GAN Loss'); plt.legend(); plt.grid(True)
plt.tight_layout(); plt.savefig(os.path.join(PLOTS_DIR,'loss_GAN.png'), dpi=200); plt.show()

plt.figure(figsize=(10,5))
plt.plot(df['epoch'], df['G_Cycle'], label='G_Cycle', linewidth=2)
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('Cycle Consistency'); plt.legend(); plt.grid(True)
plt.tight_layout(); plt.savefig(os.path.join(PLOTS_DIR,'loss_Cycle.png'), dpi=200); plt.show()

plt.figure(figsize=(10,5))
plt.plot(df['epoch'], df['G_Id'], label='G_Id', linewidth=2)
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('Identity Loss'); plt.legend(); plt.grid(True)
plt.tight_layout(); plt.savefig(os.path.join(PLOTS_DIR,'loss_Identity.png'), dpi=200); plt.show()

plt.figure(figsize=(10,5))
plt.plot(df['epoch'], df['G_CUT'], label='G_CUT', linewidth=2)
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('CUT (PatchNCE)'); plt.legend(); plt.grid(True)
plt.tight_layout(); plt.savefig(os.path.join(PLOTS_DIR,'loss_CUT.png'), dpi=200); plt.show()

plt.figure(figsize=(10,5))
plt.plot(df['epoch'], df['D_real'], label='D_real', linewidth=2)
plt.plot(df['epoch'], df['D_fake'], label='D_fake', linewidth=2)
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('Discriminator Real vs Fake'); plt.legend(); plt.grid(True)
plt.tight_layout(); plt.savefig(os.path.join(PLOTS_DIR,'loss_D_real_fake.png'), dpi=200); plt.show()

plt.figure(figsize=(10,5))
plt.plot(df['epoch'], df['lr'], label='LR', linewidth=2)
plt.xlabel('Epoch'); plt.ylabel('LR'); plt.title('Learning Rate'); plt.legend(); plt.grid(True)
plt.tight_layout(); plt.savefig(os.path.join(PLOTS_DIR,'learning_rate.png'), dpi=200); plt.show()

# %%
# -------------------------
# 12) Saliency (on G_A2B)
# -------------------------
def compute_saliency(netG, x):
    x = x.clone().detach().requires_grad_(True)
    fake = netG(x)
    score = fake.mean()
    netG.zero_grad()
    score.backward()
    sal = x.grad.abs().sum(1).squeeze().detach().cpu().numpy()
    sal = (sal - sal.min()) / (sal.max() - sal.min() + 1e-8)
    return sal

# sample a few testA images
sample_paths = test_paths[:6] if len(test_paths)>=6 else test_paths
fig, axes = plt.subplots(2, max(3,len(sample_paths)//2+len(sample_paths)%2), figsize=(15,8))
axes = axes.flatten() if hasattr(axes, 'flatten') else [axes]
for ax, p in zip(axes, sample_paths):
    x = transform(Image.open(p).convert('L')).unsqueeze(0).to(DEVICE)
    sal = compute_saliency(model.G_A2B, x)
    img_np = (x[0].detach().cpu().numpy().transpose(1,2,0)*0.5 + 0.5).squeeze()
    ax.imshow(img_np, cmap='gray')
    ax.imshow(sal, cmap='jet', alpha=0.5)
    ax.set_title(os.path.basename(p)); ax.axis('off')
plt.tight_layout(); plt.savefig(os.path.join(XAI_DIR,'saliency.png'), dpi=200); plt.show()

# %%
# -------------------------
# 13) Grad-CAM (on D_B) – Safe Version
# -------------------------
class GradCAM:
    def __init__(self, model, layer_name):
        self.model = model
        self.layer_name = layer_name
        self._feats = None
        self._grads = None
        layer = dict(self.model.named_modules())[self.layer_name]

        # Hooks — clone to avoid in-place gradient conflicts
        def save_feat(module, inp, out):
            self._feats = out.clone().detach().requires_grad_(True)
        def save_grad(module, grad_in, grad_out):
            self._grads = grad_out[0].clone().detach()

        self.h_f = layer.register_forward_hook(save_feat)
        self.h_b = layer.register_full_backward_hook(save_grad)

    def __call__(self, x):
        self.model.zero_grad(set_to_none=True)
        out = self.model(x)
        score = out.mean()
        score.backward(retain_graph=True)

        feats = self._feats
        grads = self._grads
        if feats is None or grads is None:
            raise RuntimeError("GradCAM failed to capture features or gradients.")
        w = grads.mean(dim=(2,3), keepdim=True)
        cam = (feats * w).sum(1).squeeze().detach().cpu().numpy()
        cam = np.maximum(cam, 0)
        cam = (cam - cam.min()) / (cam.max() - cam.min() + 1e-8)
        cam = np.array(Image.fromarray(cam).resize((IMAGE_SIZE, IMAGE_SIZE)))
        return cam

# pick the same layer as before
db_layers = dict(model.D_B.named_modules())
target_layer = None
for name, m in db_layers.items():
    if isinstance(m, nn.InstanceNorm2d) and m.num_features == 256:
        target_layer = name
if target_layer is None:
    target_layer = 'model.5'

gradcam = GradCAM(model.D_B, target_layer)

# Visualization
fig, axes = plt.subplots(2, max(3, len(sample_paths)//2 + len(sample_paths)%2), figsize=(15,8))
axes = axes.flatten() if hasattr(axes, "flatten") else [axes]
for ax, p in zip(axes, sample_paths):
    x = transform(Image.open(p).convert("L")).unsqueeze(0).to(DEVICE)
    cam = gradcam(x)  # Grad-CAM on D_B(x)
    img_np = (x[0].detach().cpu().numpy().transpose(1,2,0)*0.5 + 0.5).squeeze()
    ax.imshow(img_np, cmap="gray")
    ax.imshow(cam, cmap="jet", alpha=0.5)
    ax.set_title(f"Grad-CAM: {os.path.basename(p)}")
    ax.axis("off")

plt.tight_layout()
plt.savefig(os.path.join(XAI_DIR, "gradcam_fixed.png"), dpi=200)
plt.show()

# %%
# -------------------------
# 14) Feature maps (early layer of G_A2B)
# -------------------------
def visualize_feature_maps(netG, images, layer_idx=5, n_show=4, save_path=None):
    act = {}
    def hook(m, i, o): act['out'] = o.detach()
    layer = list(netG.model.children())[layer_idx]
    handle = layer.register_forward_hook(hook)

    cols = n_show+1
    fig, axes = plt.subplots(len(images), cols, figsize=(3*cols, 3*len(images)))
    if len(images)==1: axes = [axes]
    for r, img in enumerate(images):
        x = transform(Image.open(img).convert('L')).unsqueeze(0).to(DEVICE)
        _ = netG(x)
        fmap = act['out'].cpu().squeeze(0)  # (C,H,W)
        img_np = (x[0].detach().cpu().numpy().transpose(1,2,0)*0.5 + 0.5).squeeze()

        axes[r][0].imshow(img_np, cmap='gray'); axes[r][0].set_title("Input"); axes[r][0].axis('off')
        for j in range(min(n_show, fmap.shape[0])):
            axes[r][1+j].imshow(fmap[j], cmap='viridis'); axes[r][1+j].set_title(f"Map {j+1}"); axes[r][1+j].axis('off')

    handle.remove()
    plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=200)
    plt.show()

viz_samples = sample_paths[:3] if len(sample_paths)>=3 else sample_paths
visualize_feature_maps(model.G_A2B, viz_samples, layer_idx=5, n_show=4, save_path=os.path.join(XAI_DIR,'feature_maps.png'))

print(" All done.")
# Out:
#  All done.
